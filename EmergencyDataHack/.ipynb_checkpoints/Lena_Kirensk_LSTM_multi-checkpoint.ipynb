# %%
from math import sqrt
from numpy import concatenate
import matplotlib as mpl
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential
from tensorflow.keras.models import load_model
from keras.layers import LSTM, Dense, Masking
from tensorflow.keras import callbacks as cb
from keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf
from hydro_helpers.scoring import render_score
from hydro_helpers.reporting import cv_report
from hydro_helpers._utils import _nse as NSE
from hydro_helpers._utils import _rmse as RMSE
mpl.rcParams['figure.figsize'] = (20, 10)
mpl.rcParams['axes.grid'] = False
tf.random.set_seed(13)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-74856c7ca0c4> in <module>
#       8 from sklearn.preprocessing import StandardScaler
#       9 from sklearn.metrics import r2_score, mean_squared_error
# ---> 10 from keras.models import Sequential
#      11 from tensorflow.keras.models import load_model
#      12 from keras.layers import LSTM, Dense, Masking
#
# ModuleNotFoundError: No module named 'keras'

# %%
pip install tensorflow

# %%
river = 'lena'
df = pd.read_csv('data/lena/train_df.txt', index_col='date')
print(df.shape)
df.index = pd.DatetimeIndex(df.index)
# print(df.mean(axis=0))
df.head()
# Out:
# (12207, 211)
#             stage_max_3019  stage_max_3021  stage_max_3024  stage_max_3027  \
# date
# 1985-01-01           -23.0           103.0           106.0            25.0
# 1985-01-02           -23.0           103.0           106.0            23.0
# 1985-01-03           -23.0           102.0           106.0            21.0
# 1985-01-04           -24.0           102.0           106.0            19.0
# 1985-01-05           -24.0           102.0           106.0            17.0
#
#             stage_max_3028  stage_max_3029  stage_max_3030  stage_max_3031  \
# date
# 1985-01-01           258.0              51           126.0           152.0
# 1985-01-02           258.0              49           122.0           150.0
# 1985-01-03           255.0              47           120.0           147.0
# 1985-01-04           252.0              45           119.0           146.0
# 1985-01-05           251.0              43           119.0           145.0
#
#             stage_max_3032  stage_max_3035  ...  prec_30372  prec_30385  \
# date                                        ...
# 1985-01-01             143              59  ...         0.0         0.0
# 1985-01-02             141              58  ...         0.0         0.0
# 1985-01-03             140              57  ...         0.0         0.0
# 1985-01-04             139              55  ...         0.0         0.0
# 1985-01-05             135              53  ...         0.0         0.0
#
#             prec_30393  prec_30433  prec_30471  prec_30493  prec_31004  \
# date
# 1985-01-01         0.0         0.0         0.0         0.0         0.4
# 1985-01-02         0.0         0.9         0.0         0.0         0.5
# 1985-01-03         0.0         0.0         0.0         0.0         0.6
# 1985-01-04         0.6         0.3         0.0         0.2         3.0
# 1985-01-05         0.4         0.0         0.0         0.3         0.6
#
#             prec_31026  prec_31102  prec_31137
# date
# 1985-01-01         0.0         0.2         0.0
# 1985-01-02         0.7         0.0         0.7
# 1985-01-03         1.6         0.0         0.5
# 1985-01-04         0.2         0.3         0.3
# 1985-01-05         0.0         0.2         1.8
#
# [5 rows x 211 columns]

# %%
# run once
df = df.dropna(axis=0, how='all')
df = df.dropna(axis=1, how='all')
# print(df.isna().sum())
print(df.shape)
del df['stage_max_3048']
df = df.apply(lambda x: x.fillna(x.mean()),axis=0)
# print(df.isna().sum())
df = df.apply(lambda x: x.fillna(0),axis=0)
print(df.isna().sum())
# Out:
# (12207, 192)
# stage_max_3019        0
# stage_max_3021        0
# stage_max_3024        0
# stage_max_3027        0
# stage_max_3028        0
# stage_max_3029        0
# stage_max_3030        0
# stage_max_3031        0
# stage_max_3032        0
# stage_max_3035        0
# stage_max_3036        0
# stage_max_3037        0
# stage_max_3038        0
# stage_max_3041        0
# stage_max_3042        0
# stage_max_3045        0
# stage_max_3047        0
# stage_max_3050        0
# stage_max_3087        0
# stage_max_3106        0
# stage_max_3169        0
# stage_max_3180        0
# stage_max_3229        0
# stage_max_3230        0
# stage_max_3554        0
# stage_max_3555        0
# ice_thickness_3019    0
# ice_thickness_3021    0
# ice_thickness_3024    0
# ice_thickness_3027    0
#                      ..
# prec_24763            0
# prec_24817            0
# prec_24923            0
# prec_24933            0
# prec_24944            0
# prec_24951            0
# prec_24959            0
# prec_24966            0
# prec_24967            0
# prec_30028            0
# prec_30054            0
# prec_30069            0
# prec_30089            0
# prec_30219            0
# prec_30230            0
# prec_30252            0
# prec_30253            0
# prec_30328            0
# prec_30337            0
# prec_30356            0
# prec_30372            0
# prec_30385            0
# prec_30393            0
# prec_30433            0
# prec_30471            0
# prec_30493            0
# prec_31004            0
# prec_31026            0
# prec_31102            0
# prec_31137            0
# Length: 191, dtype: int64

# %%
# df.plot(subplots=True, figsize=[20,20])
# plt.show()
corr = round(df.corr(), 2)
# целевые гидропосты
# rownames = [k for k in corr.columns[corr.columns.str.contains("3019|3027|3028|3029|3030|3035|3041|3045|3050|3230|3036")].values]
rownames = [f'stage_max_{i}' for i in [3019,3027,3028,3029,3030,3035,3041,3045,3050,3230,3036]]
# позиция целевых гидропостов
# positions = [i for i, x in enumerate(corr.columns.str.contains("3019|3027|3028|3029|3030|3035|3041|3045|3050|3230|3036]")) if x]
# print(positions)
corr.to_excel('results/lena_kirensk_corr.xlsx')
corr.loc[rownames, :].transpose().style.background_gradient(cmap='coolwarm')
# corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col1 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col2 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col3 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col4 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col5 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col6 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col7 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col8 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col9 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row0_col10 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col0 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col1 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col2 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col3 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col4 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col5 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col6 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col7 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col8 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col9 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row1_col10 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col0 {
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col1 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col2 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col3 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col4 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col5 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col6 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col7 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col8 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col9 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row2_col10 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col0 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col2 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col3 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col4 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col5 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col6 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col7 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col8 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col9 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row3_col10 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col0 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col1 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col3 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col4 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col5 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col6 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col7 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col8 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col9 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row4_col10 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row5_col0 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row5_col1 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row5_col2 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row5_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_db5bc3a4_c085_11eb_ac18_00155dc83117row5_col4 {
#             background-color:  #c12b30;
#             color:  #f1f1f1

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])
        
    return np.array(data), np.array(labels)

def model_build(df, target_label):
    print(target_label)
    test_size = len(df) - int(len(df) * 0.2)
    print('Train: ', test_size)
    print('Test: ', len(df) - test_size)
    dataset = df.values
    data_mean = np.nanmean(dataset[:test_size], axis=0)
    data_std = np.nanstd(dataset[:test_size], axis=0)
    print(dataset[:test_size].shape)
#     print(np.round(data_mean, 3), np.round(data_std, 2))
    dataset = (dataset-data_mean)/data_std
#     print(dataset[:,df.columns.get_loc(target_label)])
    # shaping training and test dataset to chunks
    x_train_multi, y_train_multi = multivariate_data(dataset[:, :], dataset[:, df.columns.get_loc(target_label)], len(dataset) - test_size,
                                                     None, past_history,
                                                     future_target, STEP)
    x_val_multi, y_val_multi = multivariate_data(dataset[:, :], dataset[:, df.columns.get_loc(target_label)],
                                                 0, int(len(df) * 0.2), past_history,
                                                 future_target, STEP)
    print('\n Input training data shape:')
    print(x_train_multi.shape[-2:], y_train_multi.shape[-2:])
    print('\n Input test data shape:')
    print(x_val_multi.shape[-2:], y_val_multi.shape[-2:])
#     print('\n Single step history:')
#     print(x_train_multi[0])
#     print('\n Single step target:')
#     print(y_train_multi[0])

    # create train and test data from chunks
    train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
    val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))

    # training and test data shuffling
    train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
    val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

    multi_step_model = tf.keras.models.Sequential()
    multi_step_model.add(tf.keras.layers.LSTM(50,
                                              return_sequences=False,
                                              input_shape=x_train_multi.shape[-2:]))
    multi_step_model.add(tf.keras.layers.Dense(7))

    multi_step_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, 
                                                                beta_2=0.999, epsilon=1e-07, amsgrad=False,
                                                                name='Adam'), 
                             loss='mse')

    model_callbacks = [cb.EarlyStopping(patience=10), 
                              cb.ModelCheckpoint(filepath=f"output/"+ river + "_" + target_label + "_LSTM.h5", save_best_only=True)]
    multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=10,
                                          callbacks=model_callbacks)
    loss = multi_step_history.history['loss']
    val_loss = multi_step_history.history['val_loss']
    epochs = range(len(loss)) 
    plt.figure(figsize=[10,10])
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.legend()
    plt.show()

# %%
# define train/test split
target_labels = [f'stage_max_{i}' for i in [3019,3027,3028,3029,3030,3035,3041,3045,3050,3230,3036]]
print(target_labels)
# lookback parameters
past_history = 7 # how many instances a model sees for training, in compliance with other models' input
future_target = 7 # how many instances form a prediction step
STEP = 1 # step size - 1 for daily data
BATCH_SIZE = 30 
BUFFER_SIZE = 1000
EVALUATION_INTERVAL = len(dataset)/BATCH_SIZE # what data model sees for training
EPOCHS = 100 # how many times a model sees the data
# Out:
# ['stage_max_3019', 'stage_max_3027', 'stage_max_3028', 'stage_max_3029', 'stage_max_3030', 'stage_max_3035', 'stage_max_3041', 'stage_max_3045', 'stage_max_3050', 'stage_max_3230', 'stage_max_3036']

# %%
for l in target_labels:
    model_build(df, l)
# Out:
# stage_max_3019
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1930 - val_loss: 0.1737
# Epoch 2/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0802 - val_loss: 0.1731
# Epoch 3/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0531 - val_loss: 0.1629
# Epoch 4/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0536 - val_loss: 0.2142
# Epoch 5/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0375 - val_loss: 0.2472
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0313 - val_loss: 0.1860
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0275 - val_loss: 0.1894
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0298 - val_loss: 0.1908
# Epoch 9/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0231 - val_loss: 0.1997
# Epoch 10/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0205 - val_loss: 0.1995
# Epoch 11/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0188 - val_loss: 0.1775
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0261 - val_loss: 0.2023
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0184 - val_loss: 0.2089
# stage_max_3027
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.2078 - val_loss: 0.1876
# Epoch 2/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.1055 - val_loss: 0.1516
# Epoch 3/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0681 - val_loss: 0.1365
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0547 - val_loss: 0.1150
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0433 - val_loss: 0.1525
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0392 - val_loss: 0.1372
# Epoch 7/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0333 - val_loss: 0.1269
# Epoch 8/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0353 - val_loss: 0.1181
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0291 - val_loss: 0.1376
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0264 - val_loss: 0.1378
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0241 - val_loss: 0.1448
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0283 - val_loss: 0.1387
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0227 - val_loss: 0.1185
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0230 - val_loss: 0.1306
# stage_max_3028
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1937 - val_loss: 0.0965
# Epoch 2/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.1015
# Epoch 3/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0635 - val_loss: 0.0954
# Epoch 4/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0546 - val_loss: 0.0944
# Epoch 5/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0402 - val_loss: 0.1013
# Epoch 6/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0371 - val_loss: 0.0903
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0332 - val_loss: 0.0864
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0340 - val_loss: 0.0979
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0278 - val_loss: 0.0954
# Epoch 10/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0254 - val_loss: 0.0911
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0228 - val_loss: 0.1013
# Epoch 12/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0264 - val_loss: 0.0958
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0225 - val_loss: 0.0996
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0210 - val_loss: 0.1010
# Epoch 15/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0203 - val_loss: 0.0992
# Epoch 16/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0239 - val_loss: 0.0970
# Epoch 17/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0193 - val_loss: 0.0924
# stage_max_3029
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1616 - val_loss: 0.1118
# Epoch 2/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0786 - val_loss: 0.1131
# Epoch 3/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0507 - val_loss: 0.0984
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0463 - val_loss: 0.1069
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0328 - val_loss: 0.0937
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0294 - val_loss: 0.1125
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0250 - val_loss: 0.1110
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0278 - val_loss: 0.1157
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0214 - val_loss: 0.1109
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0206 - val_loss: 0.1230
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0184 - val_loss: 0.1167
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0204 - val_loss: 0.1140
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0172 - val_loss: 0.1051
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0159 - val_loss: 0.1248
# Epoch 15/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0151 - val_loss: 0.1052
# stage_max_3030
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1803 - val_loss: 0.0977
# Epoch 2/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0872 - val_loss: 0.0825
# Epoch 3/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0580 - val_loss: 0.0760
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0491 - val_loss: 0.0785
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0400 - val_loss: 0.0967
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0356 - val_loss: 0.0910
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0282 - val_loss: 0.0838
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0301 - val_loss: 0.0749
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0265 - val_loss: 0.0866
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0227 - val_loss: 0.0828
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0207 - val_loss: 0.0748
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0242 - val_loss: 0.0780
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0203 - val_loss: 0.0822
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0179 - val_loss: 0.0808
# Epoch 15/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0173 - val_loss: 0.0854
# Epoch 16/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0227 - val_loss: 0.0863
# Epoch 17/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0177 - val_loss: 0.0950
# Epoch 18/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0169 - val_loss: 0.0837
# Epoch 19/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0160 - val_loss: 0.0825
# Epoch 20/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0198 - val_loss: 0.0803
# Epoch 21/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0156 - val_loss: 0.0890
# stage_max_3035
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1355 - val_loss: 0.0830
# Epoch 2/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0656 - val_loss: 0.0724
# Epoch 3/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0435 - val_loss: 0.0579
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0373 - val_loss: 0.0484
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0262 - val_loss: 0.0498
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0234 - val_loss: 0.0486
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0206 - val_loss: 0.0451
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0230 - val_loss: 0.0512
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0179 - val_loss: 0.0486
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0171 - val_loss: 0.0561
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0167 - val_loss: 0.0470
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0174 - val_loss: 0.0561
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0141 - val_loss: 0.0470
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0125 - val_loss: 0.0533
# Epoch 15/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0121 - val_loss: 0.0497
# Epoch 16/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0153 - val_loss: 0.0520
# Epoch 17/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0128 - val_loss: 0.0520
# stage_max_3041
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1206 - val_loss: 0.0901
# Epoch 2/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0566 - val_loss: 0.0898
# Epoch 3/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0378 - val_loss: 0.0825
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0322 - val_loss: 0.0811
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0226 - val_loss: 0.0692
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0204 - val_loss: 0.0662
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0181 - val_loss: 0.0742
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0222 - val_loss: 0.0632
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0160 - val_loss: 0.0625
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0145 - val_loss: 0.0592
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0140 - val_loss: 0.0601
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0182 - val_loss: 0.0576
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0135 - val_loss: 0.0592
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0128 - val_loss: 0.0530
# Epoch 15/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0121 - val_loss: 0.0684
# Epoch 16/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0163 - val_loss: 0.0583
# Epoch 17/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0124 - val_loss: 0.0535
# Epoch 18/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0139 - val_loss: 0.0680
# Epoch 19/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0116 - val_loss: 0.0684
# Epoch 20/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0147 - val_loss: 0.0653
# Epoch 21/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0112 - val_loss: 0.0610
# Epoch 22/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0099 - val_loss: 0.0609
# Epoch 23/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0099 - val_loss: 0.0615
# Epoch 24/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0136 - val_loss: 0.0628
# stage_max_3045
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1167 - val_loss: 0.0543
# Epoch 2/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0543 - val_loss: 0.0606
# Epoch 3/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0371 - val_loss: 0.0394
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0332 - val_loss: 0.0336
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0223 - val_loss: 0.0438
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0205 - val_loss: 0.0524
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0178 - val_loss: 0.0366
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0208 - val_loss: 0.0309
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0148 - val_loss: 0.0381
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0155 - val_loss: 0.0385
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0141 - val_loss: 0.0332
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0186 - val_loss: 0.0272
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0134 - val_loss: 0.0360
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0123 - val_loss: 0.0295
# Epoch 15/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0122 - val_loss: 0.0324
# Epoch 16/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0164 - val_loss: 0.0306
# Epoch 17/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0118 - val_loss: 0.0363
# Epoch 18/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0150 - val_loss: 0.0538
# Epoch 19/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0139 - val_loss: 0.0356
# Epoch 20/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0149 - val_loss: 0.0262
# Epoch 21/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0108 - val_loss: 0.0346
# Epoch 22/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0095 - val_loss: 0.0382
# Epoch 23/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0095 - val_loss: 0.0317
# Epoch 24/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0144 - val_loss: 0.0314
# Epoch 25/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0113 - val_loss: 0.0374
# Epoch 26/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0100 - val_loss: 0.0392
# Epoch 27/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0109 - val_loss: 0.0326
# Epoch 28/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0147 - val_loss: 0.0299
# Epoch 29/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0096 - val_loss: 0.0430
# Epoch 30/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0119 - val_loss: 0.0459
# stage_max_3050
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1894 - val_loss: 0.1366
# Epoch 2/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0863 - val_loss: 0.0840
# Epoch 3/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0659 - val_loss: 0.0670
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0629 - val_loss: 0.0638
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0374 - val_loss: 0.0718
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0334 - val_loss: 0.0696
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0307 - val_loss: 0.0703
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0434 - val_loss: 0.0703
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0288 - val_loss: 0.0753
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0273 - val_loss: 0.0738
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0253 - val_loss: 0.0649
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0376 - val_loss: 0.0699
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0272 - val_loss: 0.0866
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0244 - val_loss: 0.0718
# stage_max_3230
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1412 - val_loss: 0.0734
# Epoch 2/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0640 - val_loss: 0.0641
# Epoch 3/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0462 - val_loss: 0.0603
# Epoch 4/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0482 - val_loss: 0.0526
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0300 - val_loss: 0.0541
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0268 - val_loss: 0.0571
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0227 - val_loss: 0.0557
# Epoch 8/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0319 - val_loss: 0.0433
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0209 - val_loss: 0.0494
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0199 - val_loss: 0.0488
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0191 - val_loss: 0.0494
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0325 - val_loss: 0.0536
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0200 - val_loss: 0.0473
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0177 - val_loss: 0.0442
# Epoch 15/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0170 - val_loss: 0.0470
# Epoch 16/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0260 - val_loss: 0.0451
# Epoch 17/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0167 - val_loss: 0.0508
# Epoch 18/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0164 - val_loss: 0.0587
# stage_max_3036
# Train:  9766
# Test:  2441
# (9766, 191)
#
#  Input training data shape:
# (7, 191) (9752, 7)
#
#  Input test data shape:
# (7, 191) (2434, 7)
# Epoch 1/100
# 407/406 [==============================] - 3s 7ms/step - loss: 0.1425 - val_loss: 0.1058
# Epoch 2/100
# 407/406 [==============================] - 3s 6ms/step - loss: 0.0629 - val_loss: 0.0796
# Epoch 3/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0407 - val_loss: 0.0680
# Epoch 4/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0347 - val_loss: 0.0648
# Epoch 5/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0249 - val_loss: 0.0666
# Epoch 6/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0228 - val_loss: 0.0784
# Epoch 7/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0199 - val_loss: 0.0698
# Epoch 8/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0242 - val_loss: 0.0573
# Epoch 9/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0186 - val_loss: 0.0622
# Epoch 10/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0175 - val_loss: 0.0787
# Epoch 11/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0144 - val_loss: 0.0666
# Epoch 12/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0159 - val_loss: 0.0651
# Epoch 13/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0128 - val_loss: 0.0748
# Epoch 14/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0122 - val_loss: 0.0802
# Epoch 15/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0117 - val_loss: 0.0651
# Epoch 16/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0148 - val_loss: 0.0571
# Epoch 17/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0113 - val_loss: 0.0621
# Epoch 18/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0099 - val_loss: 0.0647
# Epoch 19/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0094 - val_loss: 0.0681
# Epoch 20/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0112 - val_loss: 0.0681
# Epoch 21/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0091 - val_loss: 0.0713
# Epoch 22/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0090 - val_loss: 0.0638
# Epoch 23/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0084 - val_loss: 0.0645
# Epoch 24/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0106 - val_loss: 0.0681
# Epoch 25/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0101 - val_loss: 0.0631
# Epoch 26/100
# 407/406 [==============================] - 2s 6ms/step - loss: 0.0081 - val_loss: 0.0650

# %%
# validate prediction
pred = pd.DataFrame(multi_step_model.predict(x_val_multi)) * data_std[df.columns.get_loc(target_label)] + data_mean[df.columns.get_loc(target_label)]

# %%
# load trained model for time saving
# multi_step_model = load_model(f"output/"+ river + "_" + target_label + "_LSTM.h5")
# validate prediction
pred = pd.DataFrame(multi_step_model.predict(x_val_multi)) * data_std[df.columns.get_loc(target_label)] + data_mean[df.columns.get_loc(target_label)]
    for i in range(future_target):
        pred[i] = pred[i].shift(i)
        pred.columns = [f'pred_{i}' for i in range(1, future_target + 1)]
        start_index = len(df)-test_size
        pred.index = df[past_history:start_index].index.values
        pred['fact'] = df[past_history:start_index][target_label]
        fig, ax = plt.subplots()
        subdf = pred['1990-04-21':'1990-06-15']
        subdf.plot(ax=ax)
        subdf['fact'].plot(ax=ax, lw=5)
        subdf.diff().plot()
        subdf['fact'].diff().plot(lw=5)
        plt.show()
        subdf.head(7)
# Out:
#                pred_1     pred_2     pred_3     pred_4     pred_5     pred_6  \
# 1990-04-21  46.777790  44.810837  30.965385  37.299664  36.925831  66.377464
# 1990-04-22  52.758759  35.988953  46.036278  32.175167  43.814865  51.926460
# 1990-04-23  29.285568  60.440296  55.910892  46.261261  34.921879  52.996387
# 1990-04-24  21.220203  39.905388  65.536346  63.846161  38.168156  29.799297
# 1990-04-25  10.136646  35.163227  41.166252  66.413055  71.059410  44.622520
# 1990-04-26  27.654930  22.343288  34.571224  45.790085  80.085297  90.848022
# 1990-04-27  46.511585  38.186749  32.641769  52.430534  62.790646  95.112564
#
#                 pred_7  fact
# 1990-04-21   76.609695  10.0
# 1990-04-22   75.867676   9.0
# 1990-04-23   64.993813  10.0
# 1990-04-24   66.513954   5.0
# 1990-04-25   40.914856   4.0
# 1990-04-26   59.391037   3.0
# 1990-04-27  123.764473  -2.0

# %%
# test model

# %%
# расчет метрики

# квадраты стандартных отклонений по гидропостам
STATION_COEFFS = {
        3019: 185.35707752426708,
        3027: 1223.8071616577856,
        3028: 1357.4062812989373,
        3029: 1520.7730161870682,
        3030: 1765.9217904996142,
        3035: 765.3703832632036,
        3041: 443.5766934006718,
        3045: 579.1353554017562,
        3050: 612.0471238561079,
        3230: 516.6669876251401
}

def rowwise_nse(row): 
    station_id = row.station_id
    station_coeff = STATION_COEFFS[station_id]
    
    actual = row['delta_stage_max_actual']
    predicted = row['delta_stage_max_predicted']
    return np.divide(np.square(np.subtract(predicted, actual)),
            station_coeff)

def score(actual_df, predicted_df):
    merged = pd.merge(
        left=predicted_df,
        right=actual_df,
        how='right',
        on=['date', 'station_id'],
        suffixes=('_predicted', '_actual'),
    )

    merged.delta_stage_max_predicted.fillna(0, inplace=True)
    merged['error'] = merged.apply(rowwise_nse, axis=1)
    merged.dropna(inplace=True)
    if len(merged) != len(actual_df):
        return 'length of predicted df does not match actual df'
    else:
        score = np.divide(merged['error'].sum(), len(merged))
        return score
